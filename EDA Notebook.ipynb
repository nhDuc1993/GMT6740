# %%
import pandas as pd

data = pd.read_csv('all_anonymized_2015_11_2017_03.csv',low_memory=False)

# %%
IDXData = data.reset_index()
IDXData['index'] = 'AD-' + IDXData['index'].astype('str') 
IDXData.head()
# Out:
#   index  maker    model   mileage  manufacture_year  engine_displacement  \
# 0  AD-0   ford   galaxy  151000.0            2011.0               2000.0
# 1  AD-1  skoda  octavia  143476.0            2012.0               2000.0
# 2  AD-2    bmw      NaN   97676.0            2010.0               1995.0
# 3  AD-3  skoda    fabia  111970.0            2004.0               1200.0
# 4  AD-4  skoda    fabia  128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug  stk_year transmission  door_count  \
# 0         103.0       NaN        NaN       NaN          man         5.0
# 1          81.0       NaN        NaN       NaN          man         5.0
# 2          85.0       NaN        NaN       NaN          man         5.0
# 3          47.0       NaN        NaN       NaN          man         5.0
# 4          47.0       NaN        NaN       NaN          man         5.0
#
#    seat_count fuel_type                   date_created  \
# 0         7.0    diesel  2015-11-14 18:10:06.838319+00
# 1         5.0    diesel  2015-11-14 18:10:06.853411+00
# 2         5.0    diesel  2015-11-14 18:10:06.861792+00
# 3         5.0  gasoline  2015-11-14 18:10:06.872313+00
# 4         5.0  gasoline  2015-11-14 18:10:06.880335+00
#
#                  date_last_seen  price_eur
# 0  2016-01-27 20:40:15.46361+00   10584.75
# 1  2016-01-27 20:40:15.46361+00    8882.31
# 2  2016-01-27 20:40:15.46361+00   12065.06
# 3  2016-01-27 20:40:15.46361+00    2960.77
# 4  2016-01-27 20:40:15.46361+00    2738.71

# %%
Summary = IDXData.describe(include='all')

# %%
Summary
# Out:
#           index    maker    model       mileage  manufacture_year  \
# count   3552912  3033997  2419551  3.190328e+06      3.182334e+06
# unique  3552912       46     1012           NaN               NaN
# top        AD-0    skoda  octavia           NaN               NaN
# freq          1   313830   129563           NaN               NaN
# mean        NaN      NaN      NaN  1.158140e+05      2.000871e+03
# std         NaN      NaN      NaN  3.422508e+05      8.172588e+01
# min         NaN      NaN      NaN  0.000000e+00      0.000000e+00
# 25%         NaN      NaN      NaN  1.880000e+04      2.004000e+03
# 50%         NaN      NaN      NaN  8.641500e+04      2.009000e+03
# 75%         NaN      NaN      NaN  1.580250e+05      2.013000e+03
# max         NaN      NaN      NaN  9.999999e+06      2.017000e+03
#
#         engine_displacement  engine_power body_type color_slug       stk_year  \
# count          2.809498e+06  2.998035e+06   2429998     209501  536105.000000
# unique                  NaN           NaN         9         14            NaN
# top                     NaN           NaN     other      black            NaN
# freq                    NaN           NaN   1964289      42931            NaN
# mean           2.043958e+03  9.846796e+01       NaN        NaN    2021.472590
# std            1.973958e+03  4.907309e+01       NaN        NaN     140.476724
# min            0.000000e+00  1.000000e+00       NaN        NaN    2015.000000
# 25%            1.400000e+03  6.800000e+01       NaN        NaN    2017.000000
# 50%            1.798000e+03  8.600000e+01       NaN        NaN    2017.000000
# 75%            1.997000e+03  1.100000e+02       NaN        NaN    2018.000000
# max            3.276700e+04  2.237000e+03       NaN        NaN    9990.000000
#
#        transmission    door_count    seat_count fuel_type  \
# count       2811282  2.462846e+06  2.265813e+06   1705306
# unique            2           NaN           NaN         5
# top             man           NaN           NaN  gasoline
# freq        2021990           NaN           NaN    902222
# mean            NaN  4.052180e+00  4.869694e+00       NaN
# std             NaN  9.911850e-01  1.212611e+00       NaN
# min             NaN  0.000000e+00  0.000000e+00       NaN
# 25%             NaN  4.000000e+00  5.000000e+00       NaN
# 50%             NaN  4.000000e+00  5.000000e+00       NaN
# 75%             NaN  5.000000e+00  5.000000e+00       NaN
# max             NaN  7.700000e+01  5.170000e+02       NaN
#
#                          date_created                date_last_seen  \
# count                         3552912                       3552912
# unique                        3552912                       3355057
# top     2015-11-14 18:10:06.838319+00  2016-01-27 20:40:15.46361+00
# freq                                1                        197856
# mean                              NaN                           NaN
# std                               NaN                           NaN
# min                               NaN                           NaN
# 25%                               NaN                           NaN
# 50%                               NaN                           NaN
# 75%                               NaN                           NaN
# max                               NaN                           NaN
#
#            price_eur
# count   3.552912e+06
# unique           NaN
# top              NaN
# freq             NaN
# mean    1.625812e+06
# std     2.025622e+09
# min     4.000000e-02
# 25%     1.295340e+03
# 50%     7.364910e+03
# 75%     1.628423e+04
# max     2.706149e+12

# %%
IDXData[IDXData.manufacture_year==139]
# Out:
#               index       maker   model   mileage  manufacture_year  \
# 3551940  AD-3551940  volkswagen  touran     240.0             139.0
# 3552414  AD-3552414  volkswagen  touran  130000.0             139.0
#
#          engine_displacement  engine_power body_type color_slug  stk_year  \
# 3551940               1900.0          77.0     other        NaN       NaN
# 3552414               1900.0          77.0     other        NaN       NaN
#
#         transmission  door_count  seat_count fuel_type  \
# 3551940          man         NaN         NaN    diesel
# 3552414          NaN         NaN         NaN  electric
#
#                           date_created                 date_last_seen  \
# 3551940  2017-03-16 17:50:59.166248+00  2017-03-16 17:50:59.166248+00
# 3552414  2017-03-16 18:30:49.727819+00  2017-03-16 18:30:49.727819+00
#
#          price_eur
# 3551940    1295.34
# 3552414    1295.34

# %%
Summary.to_clipboard()

# %%
IDXData.to_parquet('ParquetData.parquet')

# %%
IDXData.dropna(how='any')
# Out:
#               index      maker     model   mileage  manufacture_year  \
# 1075903  AD-1075903     toyota     yaris   31696.0            2011.0
# 1075943  AD-1075943     nissan      note    9944.0            2014.0
# 1076078  AD-1076078    porsche    cayman   65000.0            2005.0
# 1076216  AD-1076216       opel     corsa   24348.0            2014.0
